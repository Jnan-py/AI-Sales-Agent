# %%
# !pip install google-generativeai pandas
# Out:
# Requirement already satisfied: google-generativeai in c:\users\lenovo\anaconda3\lib\site-packages (0.8.4)
# Requirement already satisfied: pandas in c:\users\lenovo\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in c:\users\lenovo\anaconda3\lib\site-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in c:\users\lenovo\anaconda3\lib\site-packages (from google-generativeai) (2.24.1)
# Requirement already satisfied: google-api-python-client in c:\users\lenovo\anaconda3\lib\site-packages (from google-generativeai) (2.160.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\lenovo\anaconda3\lib\site-packages (from google-generativeai) (2.38.0)
# Requirement already satisfied: protobuf in c:\users\lenovo\anaconda3\lib\site-packages (from google-generativeai) (4.25.6)
# Requirement already satisfied: pydantic in c:\users\lenovo\anaconda3\lib\site-packages (from google-generativeai) (2.10.6)
# Requirement already satisfied: tqdm in c:\users\lenovo\anaconda3\lib\site-packages (from google-generativeai) (4.66.4)
# Requirement already satisfied: typing-extensions in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from google-generativeai) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\lenovo\anaconda3\lib\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from pandas) (2024.2)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\lenovo\anaconda3\lib\site-packages (from google-api-core->google-generativeai) (1.66.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from google-api-core->google-generativeai) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from google-auth>=2.15.0->google-generativeai) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\lenovo\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\lenovo\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (4.9)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in c:\users\lenovo\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (4.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic->google-generativeai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic->google-generativeai) (2.27.2)
# Requirement already satisfied: colorama in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from tqdm->google-generativeai) (0.4.6)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\lenovo\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.70.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\lenovo\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.62.3)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\lenovo\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2024.8.30)

# %%
import pandas as pd
import sqlite3
import google.generativeai as genai
from datetime import datetime

# %%
genai.configure(api_key="AIzaSyBJjSA7JCYF05JNIcKYIBZYuiRgR2lS2sE")

# %%
# Memory Manager class
class MemoryManager:
    def __init__(self, db_file="agent_memory.db"):
        self.conn = sqlite3.connect(db_file)
        self.c = self.conn.cursor()
        self.c.execute('''
        CREATE TABLE IF NOT EXISTS memory (
            timestamp TEXT,
            agent_name TEXT,
            user_query TEXT,
            agent_response TEXT
        )
        ''')
        self.conn.commit()

    def save(self, agent_name, query, response):
        self.c.execute("INSERT INTO memory VALUES (?, ?, ?, ?)",
                       (datetime.now().strftime("%Y-%m-%d %H:%M:%S"), agent_name, query, response))
        self.conn.commit()

    def fetch_recent(self, limit=5):
        self.c.execute("SELECT timestamp, agent_name, user_query, agent_response FROM memory ORDER BY timestamp DESC LIMIT ?", (limit,))
        return self.c.fetchall()

    def pretty_print(self, limit=5):
        rows = self.fetch_recent(limit)
        for ts, agent, q, r in rows:
            print(f"--- {agent} | {ts} ---")
            print(f"Query: {q}")
            print(f"Response:\n{r}\n")

# %%
# Base Gemini Agent
class GeminiAgent:
    def __init__(self, name, role, instructions, model_name="gemini-1.5-flash"):
        self.name = name
        self.role = role
        self.instructions = instructions
        self.model = genai.GenerativeModel(model_name)

    def run(self, query, context=None):
        prompt = f"""
        You are {self.name}, role: {self.role}.
        Instructions: {self.instructions}

        User Query: {query}

        Context: {context if context else "No extra context"}
        """
        response = self.model.generate_content(prompt)
        return response.text

# %%
memory = MemoryManager()

prospecting_agent = GeminiAgent(
    name="Prospecting Agent",
    role="Helps sales reps discover high-potential leads",
    instructions="Use dataset (industry, location, SEO, ad spend) to suggest businesses. Explain reasoning."
)

# %%
df = pd.read_excel("Sample Data for the Model.xlsx")
df.head()
# Out:
#      Unnamed: 0                                         Unnamed: 1  \
# 0      Customer                                           Products
# 1      Customer     Products offered in the Market by the Customer
# 2  Acme Digital  Website Design Services\n1. Responsive Design:...
# 3           NaN                                                NaN
# 4           NaN                                                NaN
#
#                   Unnamed: 2                Unnamed: 3  \
# 0                  User Name                       UID
# 1  Sales Rep of the Customer                       UID
# 2                   John Doe  5387439f2f92e2af1a401a9c
# 3                   John Doe  538746be2f92e2af1a4a2612
# 4                   John Doe  538749ed2f92e2af1a53da57
#
#                  Unnamed: 4                     Unnamed: 5 Unnamed: 6  \
# 0             Business Name                        Address      State
# 1                       SMB    Address of the prospect/SMB        NaN
# 2       TagLine Media Group                1655 N Swan Rd,         AZ
# 3  Insight Marketing Design     401 E 8th Street Suite 304         SD
# 4           Agency Creative  14875 Landmark Blvd Suite 230         TX
#
#     Unnamed: 7 Unnamed: 8       Unnamed: 9  ...   Unnamed: 55   Unnamed: 56  \
# 0         City        Zip            Phone  ...          City         State
# 1          NaN        NaN  Prospects phone  ...  Competition3  Competition3
# 2       Tucson      85712       5202078910  ...        Tucson            AZ
# 3  Sioux Falls      57103       6052750011  ...   Sioux Falls            SD
# 4       Dallas      75254       9724881660  ...        Dallas            TX
#
#     Unnamed: 57   Unnamed: 58               Unnamed: 59         Unnamed: 60  \
# 0           Zip         Phone                     Email         Website URL
# 1  Competition3  Competition3              Competition3        Competition3
# 2         85701    5203220895      info@maddenmedia.com     maddenmedia.com
# 3         57105    6052752122                       NaN         tiger29.com
# 4         75234    9722432211  admin@milleradagency.com  milleradagency.com
#
#                                          Unnamed: 61  \
# 0                         Website Content - Scrapped
# 1                                       Competition3
# 2  https://storage.googleapis.com/buzzenginegsbuc...
# 3  https://storage.googleapis.com/buzzenginegsbuc...
# 4  https://storage.googleapis.com/buzzenginegsbuc...
#
#                                          Unnamed: 62           Unnamed: 63  \
# 0                                        All Signals  Category - Primary\n
# 1                                       Competition3          Competition3
# 2  [{"BUSINESS INFO":{"Business Name":"Madden Med...           Advertising
# 3  [{"BUSINESS INFO":{"Business Name":"Tiger29","...           Advertising
# 4  [{"BUSINESS INFO":{"Business Name":"Miller Ad ...           Advertising
#
#                    Unnamed: 64
# 0         Category - Secondary
# 1                 Competition3
# 2  Internet Marketing Services
# 3  Internet Marketing Services
# 4         Advertising Agencies
#
# [5 rows x 65 columns]

# %%
prospecting_agent = GeminiAgent(
    name="Prospecting Agent",
    role="Helps sales reps discover high-potential leads",
    instructions="""
    Suggest SMB businesses using dataset information like industry, location, SEO, ads spend.
    Always explain why you selected them.
    """,
)

# %%
insights_agent = GeminiAgent(
    name="Prospect Insights Agent",
    role="Analyzes selected prospects",
    instructions="""
    Perform SWOT analysis, review SEO, social presence, and identify opportunities.
    Suggest tailored engagement strategies.
    """,
)

# %%
communication_agent = GeminiAgent(
    name="Communication Agent",
    role="Crafts personalized communication",
    instructions="""
    Write personalized emails, LinkedIn messages, or scripts.
    Adapt tone to industry and prospect’s needs.
    Align with product features and benefits.
    """,
)

# %%
# Load your sample dataset
file_path = "Sample Data for the Model.xlsx"
df = pd.read_excel(file_path)
df.head()
# Out:
#      Unnamed: 0                                         Unnamed: 1  \
# 0      Customer                                           Products
# 1      Customer     Products offered in the Market by the Customer
# 2  Acme Digital  Website Design Services\n1. Responsive Design:...
# 3           NaN                                                NaN
# 4           NaN                                                NaN
#
#                   Unnamed: 2                Unnamed: 3  \
# 0                  User Name                       UID
# 1  Sales Rep of the Customer                       UID
# 2                   John Doe  5387439f2f92e2af1a401a9c
# 3                   John Doe  538746be2f92e2af1a4a2612
# 4                   John Doe  538749ed2f92e2af1a53da57
#
#                  Unnamed: 4                     Unnamed: 5 Unnamed: 6  \
# 0             Business Name                        Address      State
# 1                       SMB    Address of the prospect/SMB        NaN
# 2       TagLine Media Group                1655 N Swan Rd,         AZ
# 3  Insight Marketing Design     401 E 8th Street Suite 304         SD
# 4           Agency Creative  14875 Landmark Blvd Suite 230         TX
#
#     Unnamed: 7 Unnamed: 8       Unnamed: 9  ...   Unnamed: 55   Unnamed: 56  \
# 0         City        Zip            Phone  ...          City         State
# 1          NaN        NaN  Prospects phone  ...  Competition3  Competition3
# 2       Tucson      85712       5202078910  ...        Tucson            AZ
# 3  Sioux Falls      57103       6052750011  ...   Sioux Falls            SD
# 4       Dallas      75254       9724881660  ...        Dallas            TX
#
#     Unnamed: 57   Unnamed: 58               Unnamed: 59         Unnamed: 60  \
# 0           Zip         Phone                     Email         Website URL
# 1  Competition3  Competition3              Competition3        Competition3
# 2         85701    5203220895      info@maddenmedia.com     maddenmedia.com
# 3         57105    6052752122                       NaN         tiger29.com
# 4         75234    9722432211  admin@milleradagency.com  milleradagency.com
#
#                                          Unnamed: 61  \
# 0                         Website Content - Scrapped
# 1                                       Competition3
# 2  https://storage.googleapis.com/buzzenginegsbuc...
# 3  https://storage.googleapis.com/buzzenginegsbuc...
# 4  https://storage.googleapis.com/buzzenginegsbuc...
#
#                                          Unnamed: 62           Unnamed: 63  \
# 0                                        All Signals  Category - Primary\n
# 1                                       Competition3          Competition3
# 2  [{"BUSINESS INFO":{"Business Name":"Madden Med...           Advertising
# 3  [{"BUSINESS INFO":{"Business Name":"Tiger29","...           Advertising
# 4  [{"BUSINESS INFO":{"Business Name":"Miller Ad ...           Advertising
#
#                    Unnamed: 64
# 0         Category - Secondary
# 1                 Competition3
# 2  Internet Marketing Services
# 3  Internet Marketing Services
# 4         Advertising Agencies
#
# [5 rows x 65 columns]

# %%
# query1 = "Find businesses in the Computer Contractors category in Texas with low local presence but high google ads spend."
# response1 = prospecting_agent.run(query1, context=df.head().to_string())
# print("Prospecting Agent Response:\n", response1)

# # save_memory("Prospecting Agent", query1, response1)
# memory.save(agent.name, query, response)
query1 = "Find businesses in the Computer Contractors category in Texas with low local presence but high google ads spend."
response1 = prospecting_agent.run(query1, context=df.head().to_string())
print("Prospecting Agent Response:\n", response1)

# Save the interaction in memory using correct variable names
memory.save(prospecting_agent.name, query1, response1)
# Out:
# Prospecting Agent Response:
#  Based on your request to find Computer Contractors in Texas with a low local presence but high Google Ads spend, I need more information from the provided dataset.  The dataset does not seem to contain the necessary fields ("local presence" and "Google Ads spend") to directly filter and identify businesses based on those criteria.  The data includes website URLs and social media information, which could *indirectly* help assess local presence and online advertising effort, but a detailed analysis would be required and may not be entirely accurate.
#
# To fulfill your request effectively, the dataset needs to include:
#
# 1. **Local Presence:** This could be a numerical score representing the number of local listings (e.g., Google My Business, Yelp), reviews, or a combined metric.  Alternatively, a categorical variable could indicate "high," "medium," or "low" local presence.
#
# 2. **Google Ads Spend:**  A numerical field representing the estimated monthly or annual spending on Google Ads. This information is often not publicly available and would require additional data sources.
#
# **Without these fields, I cannot provide a definitive list of businesses.**  However, if you can provide a dataset with these metrics, I can help identify suitable leads.

# %%
# query2 = "What are the strengths and weaknesses of ABC Plumbing?"
# response2 = insights_agent.run(query2, context=df.head().to_string())
# print("Insights Agent Response:\n", response2)

# save_memory("Prospect Insights Agent", query2, response2)
query2 = "What are the strengths and weaknesses of ABC Plumbing?"
response2 = insights_agent.run(query2, context=df.head().to_string())
print("Insights Agent Response:\n", response2)

# Correct saving to memory
memory.save(insights_agent.name, query2, response2)
# Out:
# Insights Agent Response:
#  ## ABC Plumbing SWOT Analysis, SEO, Social Presence, and Engagement Strategies
#
# Unfortunately, the provided data does not contain information about a company called "ABC Plumbing."  The data focuses on TagLine Media Group and its competitors in the advertising and marketing space.  Therefore, I cannot perform a SWOT analysis, SEO review, or social presence analysis for ABC Plumbing.  To provide you with the requested analysis, please provide data specific to ABC Plumbing, including:
#
# * **Website URL:** To assess website content, SEO performance, and user experience.
# * **Social Media Handles (Facebook, Instagram, Twitter, LinkedIn, etc.):** To analyze social media engagement, content strategy, and brand perception.
# * **Online Reviews (Google My Business, Yelp, other review sites):** To identify customer satisfaction levels and areas for improvement.
# * **Competitor Information:** To understand the competitive landscape and identify opportunities for differentiation.
#
#
# **Once this information is provided, I can deliver a comprehensive analysis including:**
#
# * **SWOT Analysis:** Identifying ABC Plumbing's internal Strengths and Weaknesses, and external Opportunities and Threats.
# * **SEO Review:** Evaluating on-page and off-page SEO factors, keyword performance, and areas for optimization.
# * **Social Presence Analysis:** Assessing the effectiveness of ABC Plumbing's social media strategy, engagement rates, and brand voice.
# * **Opportunity Identification:** Highlighting untapped opportunities for growth and market penetration.
# * **Tailored Engagement Strategies:** Recommending specific marketing and engagement strategies based on the SWOT analysis and other findings.
#
#
# This will enable me to provide you with actionable insights to help ABC Plumbing improve its business performance.

# %%
# query3 = "Draft a personalized email for XYZ business and propose my product based on their needs."
# response3 = communication_agent.run(query3, context=df.head().to_string())
# print("Communication Agent Response:\n", response3)

# save_memory("Communication Agent", query3, response3)
query3 = "Draft a personalized email for XYZ business and propose my product based on their needs."
response3 = communication_agent.run(query3, context=df.head().to_string())
print("Communication Agent Response:\n", response3)

# Correct way to save to memory
memory.save(communication_agent.name, query3, response3)
# Out:
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# Cell In[63], line 7
#       1 # query3 = "Draft a personalized email for XYZ business and propose my product based on their needs."
#       2 # response3 = communication_agent.run(query3, context=df.head().to_string())
#       3 # print("Communication Agent Response:\n", response3)
#       4
#       5 # save_memory("Communication Agent", query3, response3)
#       6 query3 = "Draft a personalized email for XYZ business and propose my product based on their needs."
# ----> 7 response3 = communication_agent.run(query3, context=df.head().to_string())
#       8 print("Communication Agent Response:\n", response3)
#      10 # Correct way to save to memory
#
# Cell In[31], line 18, in GeminiAgent.run(self, query, context)
#       9 def run(self, query, context=None):
#      10     prompt = f"""
#      11     You are {self.name}, role: {self.role}.
#      12     Instructions: {self.instructions}
#    (...)
#      16     Context: {context if context else "No extra context"}
#      17     """
# ---> 18     response = self.model.generate_content(prompt)
#      19     return response.text
#
# File ~\anaconda3\Lib\site-packages\google\generativeai\generative_models.py:331, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330     else:
# --> 331         response = self._client.generate_content(
#     332             request,
#     333             **request_options,
#     334         )
#     335         return generation_types.GenerateContentResponse.from_response(response)
#     336 except google.api_core.exceptions.InvalidArgument as e:
#
# File ~\anaconda3\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:835, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     832 self._validate_universe_domain()
#     834 # Send the request.
# --> 835 response = rpc(
#     836     request,
#     837     retry=retry,
#     838     timeout=timeout,
#     839     metadata=metadata,
#     840 )
#     842 # Done; return the response.
#     843 return response
#
# File ~\anaconda3\Lib\site-packages\google\api_core\gapic_v1\method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\google\api_core\retry\retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File ~\anaconda3\Lib\site-packages\google\api_core\retry\retry_unary.py:153, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     149 # pylint: disable=broad-except
#     150 # This function explicitly must deal with broad exceptions.
#     151 except Exception as exc:
#     152     # defer to shared logic for handling errors
# --> 153     _retry_error_helper(
#     154         exc,
#     155         deadline,
#     156         sleep,
#     157         error_list,
#     158         predicate,
#     159         on_error,
#     160         exception_factory,
#     161         timeout,
#     162     )
#     163     # if exception not raised, sleep before next attempt
#     164     time.sleep(sleep)
#
# File ~\anaconda3\Lib\site-packages\google\api_core\retry\retry_base.py:212, in _retry_error_helper(exc, deadline, next_sleep, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     206 if not predicate_fn(exc):
#     207     final_exc, source_exc = exc_factory_fn(
#     208         error_list,
#     209         RetryFailureReason.NON_RETRYABLE_ERROR,
#     210         original_timeout,
#     211     )
# --> 212     raise final_exc from source_exc
#     213 if on_error_fn is not None:
#     214     on_error_fn(exc)
#
# File ~\anaconda3\Lib\site-packages\google\api_core\retry\retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142 for sleep in sleep_generator:
#     143     try:
# --> 144         result = target()
#     145         if inspect.isawaitable(result):
#     146             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File ~\anaconda3\Lib\site-packages\google\api_core\timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     126         remaining_timeout = self._timeout
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\google\api_core\grpc_helpers.py:78, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      76     return callable_(*args, **kwargs)
#      77 except grpc.RpcError as exc:
# ---> 78     raise exceptions.from_grpc_error(exc) from exc
#
# ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 41
# }
# ]

# %%
print("Recent Memory:")
for row in memory.fetch_recent(limit=5):
    print(row)
# Out:
# Recent Memory:
# ('2025-09-14T00:20:01.898804', 'Communication Agent', 'Draft a personalized email for XYZ business and propose my product based on their needs.', "Subject: Elevating TagLine Media Group's Digital Presence\n\nDear Leanna,\n\nMy name is [Your Name], and I'm reaching out from [Your Company]. I've been following TagLine Media Group's work, and I'm particularly impressed with your success in the advertising and advertising agencies sector in Tucson, AZ.  Your strong social media presence, particularly on Facebook and Instagram, is noteworthy.\n\nI noticed TagLine Media Group's website features a scheduler, suggesting a focus on client management and efficiency. However, based on my research,  there could be opportunities to further optimize your website's SEO and generate more leads through targeted digital marketing campaigns.\n\nOur product, [Your Product Name], is designed to help advertising agencies like TagLine Media Group achieve precisely that.  [Your Product Name] offers [mention 2-3 key features directly addressing the needs observed in the data, e.g., automated social media posting, advanced analytics dashboards for tracking campaign performance, lead generation tools through targeted ads].  This will enable you to:\n\n* **Enhance your SEO:** Improve your search engine rankings for relevant keywords, attracting more organic traffic to your website.\n* **Increase lead generation:**  Generate more qualified leads through targeted campaigns on platforms like Facebook, Instagram and Google Ads.\n* **Streamline your workflow:** Automate repetitive tasks, freeing up your team to focus on creative strategy and client interaction.\n\nI've attached a case study that showcases how we helped a similar advertising agency in [State] achieve a [quantifiable result, e.g., 30%] increase in leads within [timeframe, e.g., three months].\n\nWould you be open to a brief 15-minute call next week to discuss your specific needs and how [Your Product Name] can help TagLine Media Group reach its full potential?\n\nSincerely,\n\n[Your Name]\n\n[Your Title]\n\n[Your Company]\n\n[Your Phone Number]\n\n[Your Website]\n")
# ('2025-09-14T00:19:46.916643', 'Prospect Insights Agent', 'What are the strengths and weaknesses of ABC Plumbing?', '## ABC Plumbing SWOT Analysis, SEO, Social Presence & Engagement Strategies\n\nUnfortunately, the provided data does not contain information specifically about a company named "ABC Plumbing."  The data focuses on Tagline Media Group and several of its competitors.  Therefore, a SWOT analysis, SEO review, and social presence assessment for ABC Plumbing cannot be performed.\n\nTo provide you with the requested analysis and strategies, please provide data on ABC Plumbing, including but not limited to:\n\n* **Website URL:** This allows for an SEO audit and website content analysis.\n* **Social Media Profiles (Links):**  This enables a review of their social media presence across platforms like Facebook, Instagram, Twitter, etc.\n* **Online Reviews (Links to review platforms like Google My Business, Yelp):**  This helps assess customer perception and reputation.\n* **Competitor Information:**  Knowing their key competitors will allow for a more comprehensive SWOT analysis.\n* **Any other relevant information**: such as marketing materials, brochures, or press releases.\n\n\n**Example of how to use the provided data (for Tagline Media Group) and how the analysis would look like:**\n\n\n**Tagline Media Group SWOT Analysis (Example):**\n\n**Strengths:**\n\n* High Google reviews (100% positive) suggesting strong customer satisfaction.\n* Strong social media presence, particularly on Facebook, with regular posting and engagement.\n* Website indicates a wide range of services catering to diverse client needs (website design, SEO, social media marketing).\n* Established business with significant domain age (16 years).\n* Positive BuzzScore indicating good overall online reputation.\n\n**Weaknesses:**\n\n* Limited follower count on Instagram and Twitter compared to Facebook, indicating potential for improved reach on these platforms.\n* Missing image alt text on website, hindering SEO performance.\n* Some areas of website SEO optimization could be improved (e.g., unique titles).\n* Relatively low follower count on Instagram (41 followers).\n\n**Opportunities:**\n\n* Expand social media marketing efforts to reach a broader audience on Instagram and Twitter, focusing on visual content.\n* Leverage positive Google reviews on other platforms to boost overall online reputation.\n* Implement a more comprehensive SEO strategy to improve organic search ranking.\n* Explore paid advertising campaigns on platforms like Google Ads and Instagram to reach specific target demographics.\n* Develop case studies showcasing successful client campaigns to attract new business.\n\n**Threats:**\n\n* Intense competition from other marketing agencies in Tucson.\n* Changing algorithms and trends in digital marketing requiring constant adaptation.\n* Negative reviews could significantly damage online reputation.\n\n\n\n\nOnce you provide the necessary information about ABC Plumbing, I can perform a similar analysis and suggest tailored engagement strategies.\n')
# ('2025-09-14T00:12:20.006874', 'Prospecting Agent', 'Find businesses in the Computer Contractors category in Texas with low local presence but high google ads spend.', 'Based on the provided dataset, I cannot definitively identify Computer Contractors in Texas with low local presence and high Google Ads spend.  The dataset does not contain the necessary information to assess local presence (e.g., number of Google reviews, Yelp reviews, mentions in local directories) for each business. While Google Ads spend is indicated for some entries, the information is incomplete and not consistently linked to specific geographical locations within Texas, or even consistently associated with businesses in the Computer Contractors category.\n\nTo fulfill your request accurately, the dataset needs to include the following for each business:\n\n* **Precise Category:**  A clearly defined "Computer Contractors" category.  The current dataset\'s categories are broad.\n* **Location Data:** Street address and ideally more granular geographic data (e.g., city, county) within Texas for precise location.\n* **Local Presence Metrics:**  Quantifiable data indicating local business presence, such as number of Google reviews, Yelp reviews, and listings in relevant Texas business directories.\n* **Google Ads Spend Data:** Consistent and complete data on Google Ads spending, preferably categorized (e.g., low, medium, high) for easier filtering.\n\nOnce this improved dataset is available, I can effectively identify the businesses meeting your criteria.\n')
# ('2025-09-14T00:03:31.550302', 'Communication Agent', 'Draft a personalized email for XYZ business and propose my product based on their needs.', "Subject: Enhancing TagLine Media Group's Digital Presence\n\nDear Mr. Doe,\n\nMy name is [Your Name] and I'm reaching out from [Your Company]. I've been following TagLine Media Group's work in the Tucson advertising market, and I'm particularly impressed by your [mention a specific campaign or aspect of their work that impressed you, e.g.,  recent Copper Brothel Brewery campaign,  strong social media engagement, etc.].\n\nAt [Your Company], we specialize in [briefly describe your product/service and its core benefit, e.g.,  AI-powered marketing automation that streamlines campaign management and improves ROI].  I noticed from your online presence that you're currently utilizing [mention a specific platform or strategy they are using, e.g., Facebook ads, Google Ads, etc.], and I believe our platform could significantly enhance your efforts by:\n\n* **[Benefit 1 aligned with their current strategy, e.g., Automating ad creation and scheduling across platforms, saving you valuable time.]**\n* **[Benefit 2 addressing a potential area for improvement, e.g.,  Providing advanced analytics to optimize campaign performance and track key metrics in real-time.]**\n* **[Benefit 3 highlighting a unique feature, e.g.,  Offering A/B testing capabilities to continually refine messaging and improve conversion rates.]**\n\n\nTagLine Media Group's commitment to providing exceptional results aligns perfectly with our mission to empower marketing teams. I've attached a case study showcasing how we helped a similar agency, [Name of comparable agency], achieve [quantifiable results, e.g., a 25% increase in lead generation].\n\nWould you be open to a brief 15-minute call next week to discuss how [Your Product/Service] could specifically benefit TagLine Media Group?  Please let me know what time works best for you.\n\n\nSincerely,\n\n[Your Name]\n\n[Your Title]\n\n[Your Company]\n\n[Your Contact Information]\n")
# ('2025-09-14T00:02:44.121944', 'Prospect Insights Agent', 'What are the strengths and weaknesses of ABC Plumbing?', '## ABC Plumbing SWOT Analysis, SEO, Social Presence & Engagement Strategies\n\n**Note:**  The provided data does not contain information about a company called "ABC Plumbing." The data focuses on Tagline Media Group and several of its competitors.  Therefore, this analysis will be a general example of how such an analysis would be performed for a plumbing company, based on common industry trends.  To provide a specific analysis for ABC Plumbing,  I would need data on ABC Plumbing\'s website, social media presence, and customer reviews.\n\n\n**Hypothetical SWOT Analysis for ABC Plumbing:**\n\n**Strengths:**\n\n* **Established Reputation:**  ABC Plumbing has a long-standing presence in the community (assuming this is true; needs verification).\n* **Experienced Technicians:**  Possesses highly skilled and certified plumbers with extensive experience. (Needs verification)\n* **Emergency Service:** Offers 24/7 emergency plumbing services, catering to urgent needs. (Needs verification)\n* **Positive Customer Reviews:**  Consistently receives positive feedback from customers, highlighting excellent service and quality. (Needs verification)\n* **Competitive Pricing:** Offers competitive rates compared to other local plumbers. (Needs verification)\n\n\n**Weaknesses:**\n\n* **Limited Online Presence:** Website is outdated or lacks essential features like online booking, service descriptions, or customer testimonials. (Needs verification)\n* **Poor SEO:** Website has low search engine rankings, limiting online visibility and customer acquisition. (Needs verification)\n* **Lack of Social Media Engagement:** Minimal or no social media presence, missing opportunities for customer interaction and brand building. (Needs verification)\n* **Inefficient Scheduling:**  Difficult for customers to book appointments online, leading to delays or lost business. (Needs verification)\n* **Limited Service Area:**  Serves only a small geographical area, potentially missing out on a wider customer base. (Needs verification)\n\n\n**Opportunities:**\n\n* **Improved Website Design & Functionality:** Create a modern, user-friendly website with online booking, service descriptions, customer reviews, and a blog.\n* **Enhanced SEO:** Implement SEO strategies to improve search engine rankings for relevant keywords.\n* **Active Social Media Marketing:** Develop a consistent social media presence on platforms like Facebook, Instagram, and potentially YouTube, sharing engaging content.\n* **Targeted Advertising:** Utilize local SEO, Google My Business, and potentially paid advertising (e.g., Google Ads) to reach potential customers.\n* **Expand Service Area:** Consider expanding the service area to reach a wider customer base.\n* **Offer Value-Added Services:** Explore offering additional services like drain cleaning, water heater repair/replacement, or preventative maintenance plans.\n\n\n**Threats:**\n\n* **Intense Competition:**  Faces strong competition from other established plumbing companies. (Needs verification, competitor analysis is needed)\n* **Economic Downturn:** A decline in the economy could negatively impact demand for plumbing services.\n* **Negative Reviews:** Negative online reviews could damage reputation and deter potential customers.\n* **Supply Chain Issues:** Difficulties sourcing parts or materials could impact service delivery.\n* **Changes in Regulations:** New regulations or licensing requirements could increase operational costs.\n\n\n**Hypothetical SEO and Social Media Review (for a plumbing company):**\n\nTo evaluate SEO, I\'d need to analyze ABC Plumbing\'s website using tools like SEMrush, Ahrefs, or Moz.  This would involve looking at:\n\n* **Keyword Rankings:**  Are they ranking well for terms like "plumber [city name]", "emergency plumber [city name]", etc.?\n* **Backlinks:**  Does the website have high-quality backl ...
